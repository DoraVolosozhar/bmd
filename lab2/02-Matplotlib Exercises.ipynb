# %% [markdown]
# ___
# # Matplotlib Exercises
#
# Welcome to the exercises for reviewing matplotlib! Take your time with these, Matplotlib can be tricky to understand at first. These are relatively simple plots, but they can be hard if this is your first time with matplotlib, feel free to reference the solutions as you go along.
#
# Also don't worry if you find the matplotlib syntax frustrating, we actually won't be using it that often throughout the course, we will switch to using seaborn and pandas built-in visualization capabilities. But, those are built-off of matplotlib, which is why it is still important to get exposure to it!
#
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig=plt.figure() 
ax=fig.add_axes([0,0,1,1]) 
ax.plot(x,y) 
ax.set_xlabel('X label')
ax.set_ylabel('Y label')
ax.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
gr=plt.figure() 

ax1=gr.add_axes([0,0,1,1]) 
ax2=gr.add_axes([0.2,0.5,2,2]) 
ax1.plot(x,y,'r')
ax2.plot(x,y,'b')

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
ax1.plot(x,y,'r')
ax2.plot(x,y,'b')

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fg=plt.figure() 

ax1=fg.add_axes([0,0,1,1]) 
ax2=fg.add_axes([0.2,0.5,4,4])  
ax1.plot(x,y,'r')
ax2.plot(x,y,'b')

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
ax1= plt.axes(projection='3d')
ax1.plot3D(x, y, z, 'gray')

#ax2= plt.axes(projection='3d')
#ax2.plot3D(x, y, z, 'gray')

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y,label = 'first plot',color='g', lw=9,ls='-', marker='*', markersize=8, markerfacecolor='r') 
axes[1].plot(x,z,label = 'second plot',color='k', lw=3,ls='dotted', marker='*', markersize=4, markerfacecolor='y')

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(5,5))
axes[0].plot(x,y,label = 'first plot',color='g', lw=9,ls='-', marker='*', markersize=8, markerfacecolor='r') 
axes[1].plot(x,z,label = 'second plot',color='k', lw=3,ls='dotted', marker='*', markersize=4, markerfacecolor='y')

# %% [markdown]
# ## Exercise 5
#
# ** Save plot in png and in pdf**

# %%
fig.savefig('123.png')
fig.savefig('123.pdf')

# %% [markdown]
# ## Exercise 6
#
# ** Bield different types of plots using database from kaggle**:
# * read db in Jypyter Notebook
# * show a head of a table
# * build 3 random plots using your data. Сhoose plots from:
# https://matplotlib.org/gallery/index.html

# %%
import pandas as pd
path="D:/kpi/bmd/lab1/avocado.csv" 
data=pd.read_csv(path, encoding='utf-8') 

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Date, AveragePrice, Total Volume, 4046, 4225, 4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %%
data.head(10)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5           5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6           6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7           7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8           8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9           9  2015-10-25          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# ...

# %%
#Plotting categorical variable 
# sharey True or 'all': x- or y-axis will be shared among all subplots.
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True) #1 - num of rows, 3 num of cols
axs[0].bar(data['Date'], data["AveragePrice"])
axs[1].scatter(data['Total Volume'], data["AveragePrice"])
axs[2].plot(data['Total Volume'], data["AveragePrice"])
fig.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')
